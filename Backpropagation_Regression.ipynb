# %% [markdown]
# <a href="https://colab.research.google.com/github/affanmohd65/affanmohd65/blob/main/Backpropagation_Regression.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np

# %%
df=pd.DataFrame([[8,8,4],[7,9,5],[6,10,6],[5,12,7]], columns=['cgpa', 'profile_score', 'lpa'])

# %%
df
# Out:
#    cgpa  profile_score  lpa
# 0     8              8    4
# 1     7              9    5
# 2     6             10    6
# 3     5             12    7

# %%
def initialize_parameters(layer_dims):  ## initializing of weights and Bias

  np.random.seed(3)
  parameters={}
  L=len(layer_dims)

  for l in range(1,L):

    parameters['W' + str(l)]=np.ones((layer_dims[l-1], layer_dims[l]))*0.1
    parameters['b' + str(l)]=np.zeros((layer_dims[l],1))

  return parameters

# %%
initialize_parameters([2,2,1])
# Out:
# {'W1': array([[0.1, 0.1],
#         [0.1, 0.1]]),
#  'b1': array([[0.],
#         [0.]]),
#  'W2': array([[0.1],
#         [0.1]]),
#  'b2': array([[0.]])}

# %%
def linear_forward(A_prev, W,b):

    Z = np.dot(W.T, A_prev) + b
    return Z

# %%
def relu(Z):
    A = np.maximum(0, Z)
    return A

# %%
 ## Forward Propagation

 def L_layer_forward(X, parameters):

  A=X
  L=len(parameters) // 2

  for l in range(1, L+1):
    A_prev = A
    W1=parameters['W' + str(l)]
    b1=parameters['b' + str(l)]
    print("A"+str(l-1)+": ",A_prev)
    print("W"+str(l)+": ",W1)
    print("b"+str(l)+": ",b1)
    print("--"*20)

    A=linear_forward(A_prev,W1,b1)
    print("A"+str(l)+": ", A)
    print("**"*20)

  return A,A_prev   ## here A_prev is needed for differentiation

# %%
X = df[['cgpa', 'profile_score']].values[0].reshape(2,1)  ### Shape(no of features, no of training example)
y=df[['lpa']].values[0][0]

X
# Out:
# array([[8],
#        [8]])

# %%
y
# Out:
# np.int64(4)

# %%
## initialize parameters

X = df[['cgpa', 'profile_score']].values[0].reshape(2,1)  ### Shape(no of features, no of training example)
y=df[['lpa']].values[0][0]

parameters = initialize_parameters([2,2,1])


y_hat, A1=L_layer_forward(X, parameters)
# Out:
# A0:  [[8]
#  [8]]
# W1:  [[0.1 0.1]
#  [0.1 0.1]]
# b1:  [[0.]
#  [0.]]
# ----------------------------------------
# A1:  [[1.6]
#  [1.6]]
# ****************************************
# A1:  [[1.6]
#  [1.6]]
# W2:  [[0.1]
#  [0.1]]
# b2:  [[0.]]
# ----------------------------------------
# A2:  [[0.32]]
# ****************************************

# %%
y_hat=y_hat[0][0]   ## loss for 1st student

# %%
update_parameters(parameters,y,y_hat,A1,X)

# %%
parameters
# Out:
# {'W1': array([[0.10658137, 0.10658137],
#         [0.10658137, 0.10658137]]),
#  'b1': array([[0.00082267],
#         [0.00082267]]),
#  'W2': array([[0.111776],
#         [0.111776]]),
#  'b2': array([[0.00736]])}

# %%
## initialize parameters for 2 student

X = df[['cgpa', 'profile_score']].values[1].reshape(2,1)  ### Shape(no of features, no of training example)
y=df[['lpa']].values[1][0]


y_hat, A1=L_layer_forward(X, parameters)
# Out:
# A0:  [[7]
#  [9]]
# W1:  [[0.10658137 0.10658137]
#  [0.10658137 0.10658137]]
# b1:  [[0.00082267]
#  [0.00082267]]
# ----------------------------------------
# A1:  [[1.70612461]
#  [1.70612461]]
# ****************************************
# A1:  [[1.70612461]
#  [1.70612461]]
# W2:  [[0.111776]
#  [0.111776]]
# b2:  [[0.00736]]
# ----------------------------------------
# A2:  [[0.38876757]]
# ****************************************

# %%
update_parameters(parameters,y,y_hat,A1,X)
# Out:
# /tmp/ipykernel_1534/1945732001.py:4: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   parameters['W2'][0][0] = parameters['W2'][0][0] + (
# /tmp/ipykernel_1534/1945732001.py:8: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   parameters['W2'][1][0] = parameters['W2'][1][0] + (
# /tmp/ipykernel_1534/1945732001.py:13: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   parameters['b2'][0][0] = parameters['b2'][0][0] + (
# ...

# %%
parameters
# Out:
# {'W1': array([[0.11481311, 0.11716504],
#         [0.11481311, 0.11716504]]),
#  'b1': array([[0.00199863],
#         [0.00199863]]),
#  'W2': array([[0.12751067],
#         [0.12751067]]),
#  'b2': array([[0.01658246]])}

# %%
## initialize parameters for 3 student

X = df[['cgpa', 'profile_score']].values[2].reshape(2,1)  ### Shape(no of features, no of training example)
y=df[['lpa']].values[2][0]


y_hat, A1=L_layer_forward(X, parameters)
# Out:
# A0:  [[ 6]
#  [10]]
# W1:  [[0.11481311 0.11716504]
#  [0.11481311 0.11716504]]
# b1:  [[0.00199863]
#  [0.00199863]]
# ----------------------------------------
# A1:  [[1.83900839]
#  [1.8766392 ]]
# ****************************************
# A1:  [[1.83900839]
#  [1.8766392 ]]
# W2:  [[0.12751067]
#  [0.12751067]]
# b2:  [[0.01658246]]
# ----------------------------------------
# A2:  [[0.49036719]]
# ****************************************

# %%
update_parameters(parameters,y,y_hat,A1,X)
# Out:
# /tmp/ipykernel_1534/1945732001.py:4: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   parameters['W2'][0][0] = parameters['W2'][0][0] + (
# /tmp/ipykernel_1534/1945732001.py:8: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   parameters['W2'][1][0] = parameters['W2'][1][0] + (
# /tmp/ipykernel_1534/1945732001.py:13: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   parameters['b2'][0][0] = parameters['b2'][0][0] + (
# ...

# %%
parameters
# Out:
# {'W1': array([[0.12458335, 0.13344878],
#         [0.12461077, 0.13349447]]),
#  'b1': array([[0.00362701],
#         [0.00363158]]),
#  'W2': array([[0.1477752 ],
#         [0.14818986]]),
#  'b2': array([[0.02760173]])}

# %%
## epochs implementation

parameters = initialize_parameters([2,2,1])
epochs = 5

for i in range(epochs):

  Loss = []

  for j in range(df.shape[0]):

    X = df[['cgpa', 'profile_score']].values[j].reshape(2,1) # Shape(no of features, no of training example)
    y=df[['lpa']].values[j][0]

    y_hat, A1 = L_layer_forward(X, parameters)
    y_hat=y_hat[0][0]

    update_parameters(parameters,y,y_hat,A1,X)

    Loss.append((y-y_hat)**2)

  print('Epoch - ', i+1,'Loss - ',np.array(Loss).mean())

parameters
# Out:
# A0:  [[8]
#  [8]]
# W1:  [[0.1 0.1]
#  [0.1 0.1]]
# b1:  [[0.]
#  [0.]]
# ----------------------------------------
# A1:  [[1.6]
#  [1.6]]
# ****************************************
# A1:  [[1.6]
#  [1.6]]
# W2:  [[0.1]
#  [0.1]]
# b2:  [[0.]]
# ----------------------------------------
# A2:  [[0.32]]
# ****************************************
# A0:  [[7]
#  [9]]
# W1:  [[0.10658137 0.10658137]
#  [0.10658137 0.10658137]]
# b1:  [[0.00082267]
#  [0.00082267]]
# ----------------------------------------
# A1:  [[1.70612461]
#  [1.70612461]]
# ****************************************
# A1:  [[1.70612461]
#  [1.70612461]]
# W2:  [[0.111776]
#  [0.111776]]
# b2:  [[0.00736]]
# ----------------------------------------
# A2:  [[0.38876757]]
# ****************************************
# A0:  [[ 6]
#  [10]]
# W1:  [[0.11481311 0.11716504]
#  [0.11481311 0.11716504]]
# b1:  [[0.00199863]
#  [0.00199863]]
# ----------------------------------------
# A1:  [[1.83900839]
#  [1.8766392 ]]
# ...

# %%
def update_parameters(parameters, y, y_hat, A1, X):

    # Output weights
    parameters['W2'][0][0] = parameters['W2'][0][0] + (
        0.001 * 2 * (y - y_hat) * A1[0][0]
    )

    parameters['W2'][1][0] = parameters['W2'][1][0] + (
        0.001 * 2 * (y - y_hat) * A1[1][0]
    )

    # Output bias
    parameters['b2'][0][0] = parameters['b2'][0][0] + (
        0.001 * 2 * (y - y_hat)
    )

    # Hidden neuron 1
    parameters['W1'][0][0] = parameters['W1'][0][0] + (
        0.001 * 2 * (y - y_hat)
        * parameters['W2'][0][0] * X[0][0]
    )

    parameters['W1'][0][1] = parameters['W1'][0][1] + (
        0.001 * 2 * (y - y_hat)
        * parameters['W2'][0][0] * X[1][0]
    )

    parameters['b1'][0][0] = parameters['b1'][0][0] + (
        0.001 * 2 * (y - y_hat)
        * parameters['W2'][0][0]
    )

    # Hidden neuron 2
    parameters['W1'][1][0] = parameters['W1'][1][0] + (
        0.001 * 2 * (y - y_hat)
        * parameters['W2'][1][0] * X[0][0]
    )

    parameters['W1'][1][1] = parameters['W1'][1][1] + (
        0.001 * 2 * (y - y_hat)
        * parameters['W2'][1][0] * X[1][0]
    )

    parameters['b1'][1][0] = parameters['b1'][1][0] + (
        0.001 * 2 * (y - y_hat)
        * parameters['W2'][1][0]
    )
