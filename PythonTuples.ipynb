# %% [markdown]
# <a href="https://colab.research.google.com/github/affanmohd65/affanmohd65/blob/main/PythonTuples.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
t = (10,20,30,40,50)

t[0]
# Out:
# 10

# %%
#it will not allow this because tuple doesnt allow
# addition or subtraction of any data

t[2] = 25
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipython-input-1691910709.py in <cell line: 0>()
# ----> 1 t[2] = 25
#
# TypeError: 'tuple' object does not support item assignment

# %%
# tuple packing : putting multiple values into single tuple
# or creating tuples with parentheses


t = 10, 20, 30
print(t)
# Out:
# (10, 20, 30)

# %%
# tuple unpacking : taking values from tuple and assigning to variable

t = (10, 20, 30)
a,b,c = t

print(a)
print(b)
print(c)
# Out:
# 10
# 20
# 30
