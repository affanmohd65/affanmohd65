# %% [markdown]
# <a href="https://colab.research.google.com/github/affanmohd65/affanmohd65/blob/main/PythonList.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
nums = [10,20,30,40, 50, 60]

print(nums[0])
print(nums[-1])
nums[1:5]
# Out:
# 10
# 60
# [20, 30, 40, 50]

# %%
nums[:4]
# Out:
# [10, 20, 30, 40]

# %%
nums[::2]
# Out:
# [10, 30, 50]

# %%
nums[::-1]
# Out:
# [60, 50, 40, 30, 20, 10]

# %%
nums.append(70)

# %%
nums.insert(7, 99)

# %%
nums
# Out:
# [10, 20, 30, 40, 50, 60, 70, 99]

# %%
22 in nums
# Out:
# False

# %%
50 in nums
# Out:
# True

# %%
for x in nums:
  print(x)
# Out:
# 10
# 20
# 30
# 40
# 50
# 60
# 70
# 99

# %%
len(nums)
# Out:
# 8

# %%
max(nums)
# Out:
# 99

# %%
min(nums)
# Out:
# 10

# %%
sum(nums)
# Out:
# 379

# %%
c = nums.copy()

# %%
c
# Out:
# [10, 20, 30, 40, 50, 60, 70, 99]
